# %% [markdown]
# # Ejecución de los experimentos

# %%
import time
import random
from abia_energia import *
from problem_parameters import *
from initial_state import *
from energy_problem import *
from search import hill_climbing

# %%
random_seeds = [random.randint(0, 10000) for i in range(5)]

results = []

for i, seed in enumerate(random_seeds):
    clientes       = Clientes(ncl=1000, propc=[0.25, 0.3, 0.45], propg=0.75, seed=seed)
    centrales      = Centrales(centrales_por_tipo=[5, 10, 25], seed=seed)
    parametros     = ProblemParameters(clients_vector=clientes, power_plants_vector=centrales)
    estado_inicial = InitialState.simple_state(parametros)
    problem        = EnergyProblem(estado_inicial, used_actions=[0, 1, 2], used_heuristic=GAIN_HEURISTIC)

    start        = time.time()
    estado_final = hill_climbing(problem)
    end          = time.time()

    results.append([estado_inicial, end - start, estado_final, seed])

    print(f"Ejecucion {i}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 13
#      10 problem        = EnergyProblem(estado_inicial, used_actions=[0, 1, 2], used_heuristic=GAIN_HEURISTIC)
#      12 start        = time.time()
# ---> 13 estado_final = hill_climbing(problem)
#      14 end          = time.time()
#      16 results.append([estado_inicial, end - start, estado_final, seed])
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\search.py:643, in hill_climbing(problem)
#     641 current = Node(problem.initial)
#     642 while True:
# --> 643     neighbors = current.expand(problem)
#     644     if not neighbors:
#     645         break
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\search.py:96, in Node.expand(self, problem)
#      94 def expand(self, problem):
#      95     """List the nodes reachable in one step from this node."""
# ---> 96     return [self.child_node(problem, action)
#      97             for action in problem.actions(self.state)]
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\search.py:96, in <listcomp>(.0)
#      94 def expand(self, problem):
#      95     """List the nodes reachable in one step from this node."""
# ---> 96     return [self.child_node(problem, action)
#      97             for action in problem.actions(self.state)]
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\search.py:101, in Node.child_node(self, problem, action)
#      99 def child_node(self, problem, action):
#     100     """[Figure 3.10]"""
# --> 101     next_state = problem.result(self.state, action)
#     102     next_node = Node(next_state, self, action, problem.path_cost(self.path_cost, self.state, action, next_state))
#     103     return next_node
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\energy_problem.py:15, in EnergyProblem.result(self, state, action)
#      14 def result(self, state: StateRepresentation, action: Operator) -> StateRepresentation:
# ---> 15     return state.apply_action(action)
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\state_representation.py:105, in StateRepresentation.apply_action(self, action)
#     104 def apply_action(self, action: Operator):
# --> 105     new_state = self.copy()
#     106     new_state.last_action = action
#     108     if isinstance(action, MoveClient):
#
# File d:\Documentos\VICTOR\UNIVERSIDAD\3r CUADRI\ABIA\Practica 1\PracticaABIA1\Entrega v1.0.0\state_representation.py:41, in StateRepresentation.copy(self)
#      39 def copy(self):
#      40     return StateRepresentation(self.params,
# ---> 41                                self.c_pp.copy(),
#      42                                self.remain.copy(),
#      43                                self.consum,
#      44                                self.gain,
#      45                                self.prices,
#      46                                self.last_action,
#      47                                self.count_actions.copy())
#
# KeyboardInterrupt:

# %%
for i in results:
    print("\n-------------------------------------------\n")
    print(f"Estado iniciail: {i[0]}")
    print(f"Tiempo de ejecución: {i[1]}\n")
    print(f"Estado final: {i[2]}")
    print(f"Count actions: {i[2].count_actions}")

    print(f"Semilla: {i[3]}")
    print("\n-------------------------------------------\n")
# Out:
# -------------------------------------------
#
# Estado iniciail: Served clients = 228 of 300
# Gains: 28665.0
#
# Tiempo de ejecución: 16.81506633758545
#
# Estado final: Served clients = 294 of 300
# Gains: 30390.0
#
# Count actions: [66, 0, 0]
# Semilla: 8812
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 240 of 300
# Gains: 34110.0
#
# Tiempo de ejecución: 0.8456606864929199
#
# Estado final: Served clients = 245 of 300
# Gains: 34345.0
#
# Count actions: [5, 0, 0]
# Semilla: 3754
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 237 of 300
# Gains: 32010.0
#
# Tiempo de ejecución: 0.31600069999694824
#
# Estado final: Served clients = 239 of 300
# Gains: 32165.0
#
# Count actions: [2, 0, 0]
# Semilla: 4644
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 226 of 300
# Gains: 30021.0
#
# Tiempo de ejecución: 2.8339977264404297
#
# Estado final: Served clients = 242 of 300
# Gains: 30846.0
#
# Count actions: [16, 0, 0]
# Semilla: 1970
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 235 of 300
# Gains: 28145.0
#
# Tiempo de ejecución: 11.878747940063477
#
# Estado final: Served clients = 300 of 300
# Gains: 29625.0
#
# Count actions: [65, 0, 0]
# Semilla: 4334
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 228 of 300
# Gains: 33730.0
#
# Tiempo de ejecución: 1.6306471824645996
#
# Estado final: Served clients = 236 of 300
# Gains: 34255.0
#
# Count actions: [8, 0, 0]
# Semilla: 6848
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 223 of 300
# Gains: 33840.0
#
# Tiempo de ejecución: 0.5938246250152588
#
# Estado final: Served clients = 227 of 300
# Gains: 33985.0
#
# Count actions: [4, 0, 0]
# Semilla: 7099
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 221 of 300
# Gains: 34390.0
#
# Tiempo de ejecución: 0.622300386428833
#
# Estado final: Served clients = 225 of 300
# Gains: 34535.0
#
# Count actions: [4, 0, 0]
# Semilla: 3928
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 230 of 300
# Gains: 32595.0
#
# Tiempo de ejecución: 4.136260986328125
#
# Estado final: Served clients = 258 of 300
# Gains: 33990.0
#
# Count actions: [28, 0, 0]
# Semilla: 6467
#
# -------------------------------------------
#
#
# -------------------------------------------
#
# Estado iniciail: Served clients = 240 of 300
# Gains: 28860.0
#
# Tiempo de ejecución: 11.114057540893555
#
# Estado final: Served clients = 299 of 300
# Gains: 30085.0
#
# Count actions: [59, 0, 0]
# Semilla: 2238
#
# -------------------------------------------
